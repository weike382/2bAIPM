# %% [markdown]
# # AI工作
# :label:`chap_AI_job`

# %% [markdown]
# :begin_tab:toc
#  - [school](school.ipynb)
#  - [Layoff](Layoff.ipynb)
#  - [meeting](meeting.ipynb)
#  - [finance](finance.ipynb)
#  - [challenge](challenge.ipynb)
# :end_tab:
