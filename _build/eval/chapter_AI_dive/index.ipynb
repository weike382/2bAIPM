# %% [markdown]
# # 深入学习AI
# :label:`chap_AI_dive`
# ​

# %% [markdown]
# ```toc
# :maxdepth: 2
#
# understand_AI
# AI_Research
# code
# feature_engineering
# ML
# MLOps
# DL
# CV
# draw
# GAN
# OCR
# NLP
# KG
# Speech
# music
# FAQ
# chatbot
# video
# Federated Learning
# mobile
# cognition_AI
# real
# AI_test
# huidu
# AI_deploy
# AI_monitor&control
# develop
# ```
