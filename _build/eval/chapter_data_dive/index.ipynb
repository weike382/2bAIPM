# %% [markdown]
# # 深入学习数据
# :label:`chap_more`

# %% [markdown]
# ```toc
# :maxdepth: 2
#
# data
# data_industry
# compliance_data
# data_prepare
# information
# pirate
# law
# private
# privacy_computing
# intellectual property
# asymmetric_information
# blockchain
# data_product
# dataworks
# ```
