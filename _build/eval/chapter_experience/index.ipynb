# %% [markdown]
# # 前人经验
# :label:`chap_exper`

# %% [markdown]
# ```toc
# :maxdepth: 2
#
# early_phase
# issue
# hema
# Jamin
# taobao
# tencent
# ant_jiebei
# diudiu
# dingding
# 4years
# jubensha
# fail
# recessive_work
#
# ```
