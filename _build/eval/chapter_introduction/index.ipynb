# %% [markdown]
# # 入门
# :label:`chap_intro`

# %% [markdown]
# ```toc
# :maxdepth: 2
#
# need
# Product
# 2B
# 2C
# platform
# money
# PM
# AI
# AI_Product
# opportunity
# AI_PM
# ability
# 1Day
# career_path
# ```
