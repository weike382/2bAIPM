# %% [markdown]
# # 思维/软实力
# :label:`chap_idea`

# %% [markdown]
# ```toc
# :maxdepth: 2
#
# idea
# empathy
# create
# data
# communicate
# negotiation
# brand
# decompose
# convert
# business
# critical
# attention
# goal
# understand_tech
# design
# GTM
# time
# risk
# ```
